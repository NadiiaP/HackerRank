# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'interQuartile' function below.
#
# The function accepts following parameters:
#  1. INTEGER_ARRAY values
#  2. INTEGER_ARRAY freqs
#

def interQuartile(values, freqs):
    # Print your answer to 1 decimal place within this function
    
    S=[]
    for i in range(len(freqs)):
        l = [values[i]] * freqs[i]
        S.extend(l)
    
    S.sort()
    q = quartiles(S)
    iq = round(float(q[2] - q[0]), 1)
    print(iq)
    
    
def quartiles(arr):
    # Write your code here
    arr.sort()
    
    if len(arr)%2 == 1:
        q2 = arr[math.floor(len(arr)/2)]
        arr1 = arr[0 : math.floor(len(arr)/2)]
        arr3 = arr[math.floor(len(arr)/2)+1 : len(arr)]
    else:
        q2 = (arr[int(len(arr)/2)] + arr[int(len(arr)/2-1)])/2
        arr1 = arr[0:int(len(arr)/2)]
        arr3 = arr[int(len(arr)/2) : len(arr)]
        
    
        
    if len(arr1)%2 == 1:
        q1 = arr[math.floor(len(arr1)/2)]
        q3 = arr3[math.floor(len(arr3)/2)]
    else: 
        q1 = (arr1[int(len(arr1)/2)] + arr1[int(len(arr1)/2-1)])/2
        q3 = (arr3[int(len(arr3)/2)] + arr3[int(len(arr3)/2-1)])/2
    
    return [q1, q2, q3]

if __name__ == '__main__':
    n = int(input().strip())

    val = list(map(int, input().rstrip().split()))

    freq = list(map(int, input().rstrip().split()))

    interQuartile(val, freq)
